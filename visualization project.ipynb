# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

#cufflinks library

from IPython.display import display,HTML
import chart_studio.plotly as cp
import plotly.graph_objs as go
import plotly
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import cufflinks as cf
cf.set_config_file(offline=True)
import plotly.express as px
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
dataframe = pd.read_csv("./loss stats bcmm.csv")

# %%
dataframe
# Out:
#     Unnamed: 0  Unnamed: 1    Unnamed: 2 Unnamed: 3        Unnamed: 4  \
# 0          NaN         NaN           NaN        NaN               NaN
# 1          NaN         NaN           NaN        NaN               NaN
# 2          NaN         NaN           NaN        NaN               NaN
# 3          NaN         NaN           NaN        NaN               NaN
# 4          NaN         NaN           NaN        NaN               NaN
# 5      2020/21         NaN           NaN        NaN               NaN
# 6    Financial         NaN     Technical   Non Tech    Non Tech Total
# 7       Period       Month  Loss % (Est)     Loss %  Rand loss (cost)
# 8            1  2020/07/01         5,90%     20,03%      R 41 050 094
# 9            2  2020/08/01         5,90%     14,27%      R 26 943 936
# 10           3  2020/09/01         5,90%     14,06%      R 16 938 223
# 11           4  2020/10/01         5,90%     30,37%      R 37 211 542
# ...

# %%
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 1, Unnamed: 2, Unnamed: 3, Unnamed: 4, Directorate of Infrastructure Services Electrical, Unnamed: 6, Unnamed: 7, Unnamed: 8, Unnamed: 9, Unnamed: 10, Unnamed: 11]
# Index: []

# %%
dataframe.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22     True
# 23     True
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# dtype: bool

# %%
dataframe.drop_duplicates()
# Out:
#     Unnamed: 0  Unnamed: 1    Unnamed: 2 Unnamed: 3        Unnamed: 4  \
# 0          NaN         NaN           NaN        NaN               NaN
# 1          NaN         NaN           NaN        NaN               NaN
# 2          NaN         NaN           NaN        NaN               NaN
# 3          NaN         NaN           NaN        NaN               NaN
# 4          NaN         NaN           NaN        NaN               NaN
# 5      2020/21         NaN           NaN        NaN               NaN
# 6    Financial         NaN     Technical   Non Tech    Non Tech Total
# 7       Period       Month  Loss % (Est)     Loss %  Rand loss (cost)
# 8            1  2020/07/01         5,90%     20,03%      R 41 050 094
# 9            2  2020/08/01         5,90%     14,27%      R 26 943 936
# 10           3  2020/09/01         5,90%     14,06%      R 16 938 223
# 11           4  2020/10/01         5,90%     30,37%      R 37 211 542
# ...

# %%
dataframe.drop(columns=['Directorate of Infrastructure Services Electrical','Unnamed: 6','Unnamed: 11'], inplace=True)

# %%
dataframe
# Out:
#     Unnamed: 0  Unnamed: 1    Unnamed: 2 Unnamed: 3        Unnamed: 4  \
# 0          NaN         NaN           NaN        NaN               NaN
# 1          NaN         NaN           NaN        NaN               NaN
# 2          NaN         NaN           NaN        NaN               NaN
# 3          NaN         NaN           NaN        NaN               NaN
# 4          NaN         NaN           NaN        NaN               NaN
# 5      2020/21         NaN           NaN        NaN               NaN
# 6    Financial         NaN     Technical   Non Tech    Non Tech Total
# 7       Period       Month  Loss % (Est)     Loss %  Rand loss (cost)
# 8            1  2020/07/01         5,90%     20,03%      R 41 050 094
# 9            2  2020/08/01         5,90%     14,27%      R 26 943 936
# 10           3  2020/09/01         5,90%     14,06%      R 16 938 223
# 11           4  2020/10/01         5,90%     30,37%      R 37 211 542
# ...

# %%
dataframe.drop(columns=['Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 0'], inplace=True)

# %%
dataframe.drop(index=[1,2,3,4,5], inplace=True)

# %%
dataframe.drop(index=[0,21], inplace=True)

# %%
dataframe.rename(columns={'Unnamed: 1': 'Month', 'Unnamed: 2': 'Technical loss(%) est', 'Unnamed: 3': 'Non-technical loss(%) est'}, inplace=True)
dataframe.columns = dataframe.columns.str.upper()

# %%
dataframe.rename(columns={'TECHNICAL LOSS': 'Technical loss(%) est', 'NON-TECHNICAL LOSS': 'Non-technical loss(%) est'}, inplace=True)
dataframe.columns = dataframe.columns.str.upper()

# %%
dataframe= dataframe.drop('UNNAMED: 11', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 dataframe= dataframe.drop('UNNAMED: 11', axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %%
dataframe
# Out:
#          MONTH TECHNICAL LOSS(%) EST NON-TECHNICAL LOSS(%) EST  \
# 6          NaN             Technical                  Non Tech
# 7        Month          Loss % (Est)                    Loss %
# 8   2020/07/01                 5,90%                    20,03%
# 9   2020/08/01                 5,90%                    14,27%
# 10  2020/09/01                 5,90%                    14,06%
# 11  2020/10/01                 5,90%                    30,37%
# 12  2020/11/01                 5,90%                    12,91%
# 13  2020/12/01                 5,90%                     0,13%
# 14  2021/01/01                 5,90%                     2,06%
# 15  2021/02/01                 5,90%                    16,14%
# 16  2021/03/01                 5,90%                    17,11%
# 17  2021/04/01                 5,90%                    26,36%
# 18  2021/05/01                 5,90%                    20,61%
# 19  2021/06/01                 5,90%                    24,27%
# ...

# %%
dataframe.drop(index=[6,7,20,22,23,36], inplace=True)

# %%
dataframe
# Out:
#          MONTH TECHNICAL LOSS(%) EST NON-TECHNICAL LOSS(%) EST    UNNAMED: 4
# 8   2020/07/01                 5,90%                    20,03%  R 41 050 094
# 9   2020/08/01                 5,90%                    14,27%  R 26 943 936
# 10  2020/09/01                 5,90%                    14,06%  R 16 938 223
# 11  2020/10/01                 5,90%                    30,37%  R 37 211 542
# 12  2020/11/01                 5,90%                    12,91%  R 15 316 850
# 13  2020/12/01                 5,90%                     0,13%     R 143 301
# 14  2021/01/01                 5,90%                     2,06%   R 2 330 138
# 15  2021/02/01                 5,90%                    16,14%  R 18 086 156
# 16  2021/03/01                 5,90%                    17,11%  R 20 490 179
# 17  2021/04/01                 5,90%                    26,36%  R 30 439 552
# 18  2021/05/01                 5,90%                    20,61%  R 23 560 268
# ...

# %%
dataframe['NON-TECHNICAL LOSS(%) EST'] = dataframe['NON-TECHNICAL LOSS(%) EST'].str.rstrip('%').str.replace(',', '.').astype(float)


dataframe['NON-TECHNICAL LOSS(%) EST'] = dataframe['NON-TECHNICAL LOSS(%) EST'].round(0)



fig = px.line(dataframe, x="MONTH", y="NON-TECHNICAL LOSS(%) EST", title='Non technical losses Buffalo City Metro Municipality made between 2020 till 2022')
fig.update_yaxes(title_text='NON-TECHNICAL LOSS(%) EST' ) 
fig.update_traces(line_color='#FF0000')
fig.show()
# Out:
# <div>                            <div id="d20cb2c9-fa0c-43e4-8311-d00d2874daa1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d20cb2c9-fa0c-43e4-8311-d00d2874daa1")) {                    Plotly.newPlot(                        "d20cb2c9-fa0c-43e4-8311-d00d2874daa1",                        [{"hovertemplate":"MONTH=%{x}<br>NON-TECHNICAL LOSS(%) EST=%{y}<extra></extra>","legendgroup":"","line":{"color":"#FF0000","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020/07/01","2020/08/01","2020/09/01","2020/10/01","2020/11/01","2020/12/01","2021/01/01","2021/02/01","2021/03/01","2021/04/01","2021/05/01","2021/06/01","2021/07/01","2021/08/01","2021/09/01","2021/10/01","2021/11/01","2021/12/01"
# ...
